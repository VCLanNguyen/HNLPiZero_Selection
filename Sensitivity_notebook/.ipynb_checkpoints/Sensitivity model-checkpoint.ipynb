# %%
# Add the relevant scripts from LArMachineLearningData
# Nice the process so it can run with lots of cores on low priority
import os
os.nice(20)

# Add local paths
import sys
hnlDIR = os.environ['_']
sys.path.append('../pyscript')
sys.path.append('../bdtscript')

# From pyscript Library
from Plotting import *
from Dictionary import *
from HelperFunctions import *
from CutFunctions import *

# From BDT Library
from importlib import reload
from PandoraBDT import *

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
true_counts = 1035.7422651033662
start_counts =  986.0935252916531

# %%
simU = 1e-7 #already squared
scaleHNLPlot = 80

# %%
plotU = getUfromScaleFactor(simU, scaleHNLPlot)
true_counts = 1035.7422651033662 * scaleHNLPlot
start_counts =  986.0935252916531 * scaleHNLPlot

print("Scale Umu by " + str(scaleHNLPlot))
print("Scaled Umu = " + str(plotU))
print("Scaled true counts = " + str(true_counts))
print("Scaled start counts = " + str(start_counts))
# Out:
# Scale Umu by 80
# Scaled Umu = 8.944271909999158e-07
# Scaled true counts = 82859.3812082693
# Scaled start counts = 78887.48202333225

# %%
#read in hdf5 to dataframe
hnl_path = "../hdf5_files/hnl_clearcos_bdt_20k.h5"

df_hnl, dfsubrun_hnl, dfmevprtl_hnl, dfmct_hnl = hdf5_to_dataframe(hnl_path)

scale_pot_hnl, hnl_spill = calc_scaling_pot(dfsubrun_hnl, df_hnl, ifScale = scaleHNLPlot)

del dfsubrun_hnl, dfmevprtl_hnl, dfmct_hnl
# Out:
# -----------------------------------------------
# sample pot = 1.3514945244223486e+22
# sample spill = 20000
# target spill = 1479.8432134638754
# scale pot factor = 5.9193728538555
# -----------------------------------------------

# %%
#read in hdf5 to dataframe
nu_path = "../hdf5_files/nu_clearcos_bdt_20k.h5"

df_nu, dfsubrun_nu, _, dfmct_nu = hdf5_to_dataframe(nu_path)

scale_pot_nu, nu_spill = calc_scaling_pot(dfsubrun_nu, df_nu)

del  dfsubrun_nu, dfmct_nu
# Out:
# -----------------------------------------------
# sample pot = 2.1545969640795046e+18
# sample spill = 19900
# target spill = 9236066.10970129
# scale pot factor = 464.12392511061756
# -----------------------------------------------

# %%
#read in hdf5 to dataframe
cos_path = "../hdf5_files/cosmics_clearcos_bdt_20k.h5"

df_cos, _, _, _ = hdf5_to_dataframe(cos_path) 

df_cos, dfsubrun_cosmics, _, _ = hdf5_to_dataframe(cos_path)

scale_pot_cosmics = calc_scaling_spill(dfsubrun_cosmics, df_cos, hnl_spill, nu_spill)

del  dfsubrun_cosmics
# Out:
# -----------------------------------------------
# target total spill = 200000000.0
# hnl + nu spill = 9237545.952914754
# target intime spill = 190762454.04708523
# scale pot factor = 99.09737872575856
# -----------------------------------------------

# %%
df_hnl = df_hnl.drop(['slc_is_clear_cosmics'], axis=1)

df_nu = df_nu.drop(['slc_is_clear_cosmics'], axis=1)

df_cos = df_cos.drop(['slc_is_clear_cosmics'], axis=1)

# %% [markdown]
# <h1> CRUMBS </h1>

# %%
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_crumbs_score', 
                    scaleHNLPlot,
                    xmin = -1.5, xmax =0.5, xnbin = 40,
                    xtitle = 'CRUMBS Score'
                    )

plt.show()
# Out:
# nSig = 78538.2, nBkg = 2.49048e+07, nSlc = 2.49833e+07
# purity = 0.314
# eff = 94.8
# select eff = 99.6

# %%
df_hnl = cutCosmics(df_hnl, crumbsScore = 0)
df_nu = cutCosmics(df_nu, crumbsScore = 0)
df_cos = cutCosmics(df_cos, crumbsScore = 0)

# %%
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_crumbs_score', 
                    scaleHNLPlot,
                    xmin = -1.5, xmax =0.5, xnbin = 40,
                    xtitle = 'CRUMBS Score'
                    )
#plt.yscale('log')

plt.show()
# Out:
# nSig = 74157.9, nBkg = 7.28832e+06, nSlc = 7.36248e+06
# purity = 1.01
# eff = 89.5
# select eff = 94

# %% [markdown]
# <h1> Fiducial Volume </h1>

# %%
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_is_fv', 
                    scaleHNLPlot,
                    xmin = -1, xmax = 3, xnbin = 40,
                    xtitle = 'Vertex is in Fiducial Volume'
                    )
plt.show()
# Out:
# nSig = 74157.9, nBkg = 7.28832e+06, nSlc = 7.36248e+06
# purity = 1.01
# eff = 89.5
# select eff = 94

# %%
df_hnl = cutFV(df_hnl)
df_nu = cutFV(df_nu)
df_cos = cutFV(df_cos)

# %%
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_is_fv', 
                    scaleHNLPlot,
                    xmin = -1, xmax = 3, xnbin = 40,
                    xtitle = 'Vertex is in Fiducial Volume'
                    )
plt.show()
# Out:
# nSig = 69694.7, nBkg = 5.03985e+06, nSlc = 5.10955e+06
# purity = 1.36
# eff = 84.1
# select eff = 88.3

# %% [markdown]
# <h1>Containment</h1>

# %%
#----------------------------------------------
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_pfp_shower_end_x', 
                    scaleHNLPlot,
                    xmin = -500, xmax = 200, xnbin = 40,
                    xtitle = 'Shower End X [cm]'
                    )
plt.show()
#----------------------------------------------
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_pfp_shower_end_y', 
                    scaleHNLPlot,
                    xmin = -500, xmax = 200, xnbin = 40,
                    xtitle = 'Shower End Y [cm]'
                    )
plt.show()
#----------------------------------------------
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_pfp_shower_end_z', 
                    scaleHNLPlot,
                    xmin = 0, xmax = 500, xnbin = 40,
                    xtitle = 'Shower End Z [cm]'
                    )
plt.show()

#----------------------------------------------
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_pfp_track_end_x', 
                    scaleHNLPlot,
                    xmin = -500, xmax = 200, xnbin = 40,
                    xtitle = 'Track End X [cm]'
                    )
plt.show()
#----------------------------------------------
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_pfp_track_end_y', 
                    scaleHNLPlot,
                    xmin = -500, xmax = 200, xnbin = 40,
                    xtitle = 'Track End Y [cm]'
                    )
plt.show()
#----------------------------------------------
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_pfp_track_end_z', 
                    scaleHNLPlot,
                    xmin = 0, xmax = 500, xnbin = 40,
                    xtitle = 'Track End Z [cm]'
                    )
plt.show()
# Out:
# nSig = 69694.7, nBkg = 5.03985e+06, nSlc = 5.10955e+06
# purity = 1.36
# eff = 84.1
# select eff = 88.3
# nSig = 69694.7, nBkg = 5.03985e+06, nSlc = 5.10955e+06
# purity = 1.36
# eff = 84.1
# select eff = 88.3
# nSig = 69694.7, nBkg = 5.03985e+06, nSlc = 5.10955e+06
# purity = 1.36
# eff = 84.1
# select eff = 88.3
# nSig = 69694.7, nBkg = 5.03985e+06, nSlc = 5.10955e+06
# purity = 1.36
# eff = 84.1
# select eff = 88.3
# nSig = 69694.7, nBkg = 5.03985e+06, nSlc = 5.10955e+06
# purity = 1.36
# eff = 84.1
# select eff = 88.3
# nSig = 69694.7, nBkg = 5.03985e+06, nSlc = 5.10955e+06
# purity = 1.36
# eff = 84.1
# select eff = 88.3

# %%
df_hnl = cutContainment(df_hnl)
df_nu = cutContainment(df_nu)
df_cos = cutContainment(df_cos)

# %%
#----------------------------------------------
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_pfp_shower_end_x', 
                    scaleHNLPlot,
                    xmin = -500, xmax = 200, xnbin = 40,
                    xtitle = 'Shower End X [cm]'
                    )
plt.show()
#----------------------------------------------
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_pfp_shower_end_y', 
                    scaleHNLPlot,
                    xmin = -500, xmax = 200, xnbin = 40,
                    xtitle = 'Shower End Y [cm]'
                    )
plt.show()
#----------------------------------------------
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_pfp_shower_end_z', 
                    scaleHNLPlot,
                    xmin = 0, xmax = 500, xnbin = 40,
                    xtitle = 'Shower End Z [cm]'
                    )
plt.show()

#----------------------------------------------
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_pfp_track_end_x', 
                    scaleHNLPlot,
                    xmin = -500, xmax = 200, xnbin = 40,
                    xtitle = 'Track End X [cm]'
                    )
plt.show()
#----------------------------------------------
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_pfp_track_end_y', 
                    scaleHNLPlot,
                    xmin = -500, xmax = 200, xnbin = 40,
                    xtitle = 'Track End Y [cm]'
                    )
plt.show()
#----------------------------------------------
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_pfp_track_end_z', 
                    scaleHNLPlot,
                    xmin = 0, xmax = 500, xnbin = 40,
                    xtitle = 'Track End Z [cm]'
                    )
plt.show()
# Out:
# nSig = 58335.4, nBkg = 3.07807e+06, nSlc = 3.1364e+06
# purity = 1.86
# eff = 70.4
# select eff = 73.9
# nSig = 58335.4, nBkg = 3.07807e+06, nSlc = 3.1364e+06
# purity = 1.86
# eff = 70.4
# select eff = 73.9
# nSig = 58335.4, nBkg = 3.07807e+06, nSlc = 3.1364e+06
# purity = 1.86
# eff = 70.4
# select eff = 73.9
# nSig = 58335.4, nBkg = 3.07807e+06, nSlc = 3.1364e+06
# purity = 1.86
# eff = 70.4
# select eff = 73.9
# nSig = 58335.4, nBkg = 3.07807e+06, nSlc = 3.1364e+06
# purity = 1.86
# eff = 70.4
# select eff = 73.9
# nSig = 58335.4, nBkg = 3.07807e+06, nSlc = 3.1364e+06
# purity = 1.86
# eff = 70.4
# select eff = 73.9

# %% [markdown]
# <h1> Opt0 </h1>

# %%
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_opt0_score', 
                    scaleHNLPlot,
                    xmin = 0, xmax = 40000, xnbin = 40,
                    xtitle = 'Opt0 Score'
                    )
plt.show()
#----------------------------------------------
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_opt0_frac', 
                    scaleHNLPlot,
                    xmin = 0, xmax = 2, xnbin = 40,
                    xtitle = 'Opt0 Fraction'
                    )
plt.show()
#----------------------------------------------
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_opt0_time_corrected_Z_pandora', 
                    scaleHNLPlot,
                    xmin = 0, xmax = 3000, xnbin = 40,
                    xtitle = 'Opt0 Time Corrected Z'
                    )
plt.show()
# Out:
# nSig = 58335.4, nBkg = 3.07807e+06, nSlc = 3.1364e+06
# purity = 1.86
# eff = 70.4
# select eff = 73.9
# nSig = 58335.4, nBkg = 3.07807e+06, nSlc = 3.1364e+06
# purity = 1.86
# eff = 70.4
# select eff = 73.9
# nSig = 58335.4, nBkg = 3.07807e+06, nSlc = 3.1364e+06
# purity = 1.86
# eff = 70.4
# select eff = 73.9

# %%
df_hnl = cutOpt0(df_hnl)
df_nu = cutOpt0(df_nu)
df_cos = cutOpt0(df_cos)

# %%
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_opt0_score', 
                    scaleHNLPlot,
                    xmin = 0, xmax = 40000, xnbin = 40,
                    xtitle = 'Opt0 Score'
                    )
plt.show()
#----------------------------------------------
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_opt0_frac', 
                    scaleHNLPlot,
                    xmin = 0, xmax = 2, xnbin = 40,
                    xtitle = 'Opt0 Fraction'
                    )
plt.show()
#----------------------------------------------
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_opt0_time_corrected_Z_pandora', 
                    scaleHNLPlot,
                    xmin = 0, xmax = 3000, xnbin = 40,
                    xtitle = 'Opt0 Time Corrected Z'
                    )
plt.show()
# Out:
# nSig = 55529.6, nBkg = 2.7778e+06, nSlc = 2.83333e+06
# purity = 1.96
# eff = 67
# select eff = 70.4
# nSig = 55529.6, nBkg = 2.7778e+06, nSlc = 2.83333e+06
# purity = 1.96
# eff = 67
# select eff = 70.4
# nSig = 55529.6, nBkg = 2.7778e+06, nSlc = 2.83333e+06
# purity = 1.96
# eff = 67
# select eff = 70.4

# %% [markdown]
# <h1>Muon Rejection</h1>

# %%
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_n_razzled_muons', 
                    scaleHNLPlot,
                    xmin = 0, xmax = 5, xnbin = 5,
                    xtitle = 'n Razzled Muons'
                    )
plt.show()
#----------------------------------------------
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_pfp_razzled_muon_score', 
                    scaleHNLPlot,
                    xmin = 0, xmax = 1, xnbin = 40,
                    xtitle = 'PFP Razzled Muon Score'
                    )
plt.show()
# Out:
# nSig = 55529.6, nBkg = 2.7778e+06, nSlc = 2.83333e+06
# purity = 1.96
# eff = 67
# select eff = 70.4
# nSig = 55529.6, nBkg = 2.7778e+06, nSlc = 2.83333e+06
# purity = 1.96
# eff = 67
# select eff = 70.4

# %%
df_hnl = cutMuon(df_hnl, muonScore = 0.04)
df_nu = cutMuon(df_nu, muonScore = 0.04)
df_cos = cutMuon(df_cos, muonScore = 0.04)

# %%
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_n_razzled_muons', 
                    scaleHNLPlot,
                    xmin = 0, xmax = 5, xnbin = 5,
                    xtitle = 'n Razzled Muons'
                    )
plt.show()
#----------------------------------------------
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_pfp_razzled_muon_score', 
                    scaleHNLPlot,
                    xmin = 0, xmax = 1, xnbin = 40,
                    xtitle = 'PFP Razzled Muon Score'
                    )
#plt.xlim(0,0.04)
plt.show()
# Out:
# nSig = 48296.2, nBkg = 609063, nSlc = 657359
# purity = 7.35
# eff = 58.3
# select eff = 61.2
# nSig = 48296.2, nBkg = 609063, nSlc = 657359
# purity = 7.35
# eff = 58.3
# select eff = 61.2

# %% [markdown]
# <h1>Proton Rejection</h1>

# %%
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_n_razzled_protons_thresh', 
                    scaleHNLPlot,
                    xmin = 0, xmax = 5, xnbin = 5,
                    xtitle = 'n Razzled Protons'
                    )
plt.show()
#----------------------------------------------
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_pfp_razzled_proton_score', 
                    scaleHNLPlot,
                    xmin = 0, xmax = 1, xnbin = 40,
                    xtitle = 'PFP Razzled Proton Score'
                    )
#plt.xlim(0,0.04)
plt.show()
# Out:
# nSig = 48296.2, nBkg = 609063, nSlc = 657359
# purity = 7.35
# eff = 58.3
# select eff = 61.2
# nSig = 48296.2, nBkg = 609063, nSlc = 657359
# purity = 7.35
# eff = 58.3
# select eff = 61.2

# %%
df_hnl = cutProton(df_hnl, nProton = 0, protonScore = 0.025)
df_nu = cutProton(df_nu, nProton = 0, protonScore = 0.025)
df_cos = cutProton(df_cos, nProton = 0, protonScore = 0.025)

# %%
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_n_razzled_protons_thresh', 
                    scaleHNLPlot,
                    xmin = 0, xmax = 5, xnbin = 5,
                    xtitle = 'n Razzled Protons'
                    )
plt.show()
#----------------------------------------------
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_pfp_razzled_proton_score', 
                    scaleHNLPlot,
                    xmin = 0, xmax = 1, xnbin = 40,
                    xtitle = 'PFP Razzled Proton Score'
                    )
plt.show()
# Out:
# nSig = 27720.4, nBkg = 56939.9, nSlc = 84660.4
# purity = 32.7
# eff = 33.5
# select eff = 35.1
# nSig = 27720.4, nBkg = 56939.9, nSlc = 84660.4
# purity = 32.7
# eff = 33.5
# select eff = 35.1

# %% [markdown]
# <h1>Pion Rejection</h1>

# %%
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_n_razzled_pions_thresh', 
                    scaleHNLPlot,
                    xmin = 0, xmax = 5, xnbin = 5,
                    xtitle = 'n Razzled Pions'
                    )
plt.show()
#----------------------------------------------
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_pfp_razzled_pion_score', 
                    scaleHNLPlot,
                    xmin = 0, xmax = 1, xnbin = 40,
                    xtitle = 'PFP Razzled Pion Score'
                    )
plt.show()
# Out:
# nSig = 27720.4, nBkg = 56939.9, nSlc = 84660.4
# purity = 32.7
# eff = 33.5
# select eff = 35.1
# nSig = 27720.4, nBkg = 56939.9, nSlc = 84660.4
# purity = 32.7
# eff = 33.5
# select eff = 35.1

# %%
df_hnl = cutPion(df_hnl, nPion = 0, pionScore = 0.7)
df_nu = cutPion(df_nu, nPion = 0, pionScore = 0.7)
df_cos = cutPion(df_cos, nPion = 0, pionScore = 0.7)

# %%
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_n_razzled_pions_thresh', 
                    scaleHNLPlot,
                    xmin = 0, xmax = 5, xnbin = 5,
                    xtitle = 'n Razzled Pions'
                    )
plt.show()
#----------------------------------------------
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_pfp_razzled_pion_score', 
                    scaleHNLPlot,
                    xmin = 0, xmax = 1, xnbin = 40,
                    xtitle = 'PFP Razzled Pion Score'
                    )
plt.show()
# Out:
# nSig = 27596.1, nBkg = 54972.5, nSlc = 82568.6
# purity = 33.4
# eff = 33.3
# select eff = 35
# nSig = 27596.1, nBkg = 54972.5, nSlc = 82568.6
# purity = 33.4
# eff = 33.3
# select eff = 35

# %% [markdown]
# <h1>Electron Rejection (?)</h1>

# %%
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_n_razzled_electrons', 
                    scaleHNLPlot,
                    xmin = 0, xmax = 5, xnbin = 5,
                    xtitle = 'n Razzled Electrons'
                    )
plt.show()
#----------------------------------------------
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_pfp_razzled_electron_score', 
                    scaleHNLPlot,
                    xmin = 0, xmax = 1, xnbin = 40,
                    xtitle = 'PFP Razzled Electron Score'
                    )
plt.show()
# Out:
# nSig = 27596.1, nBkg = 54972.5, nSlc = 82568.6
# purity = 33.4
# eff = 33.3
# select eff = 35
# nSig = 27596.1, nBkg = 54972.5, nSlc = 82568.6
# purity = 33.4
# eff = 33.3
# select eff = 35

# %% [markdown]
# <h1>Photon Selection</h1>

# %%
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_n_razzled_photons', 
                    scaleHNLPlot,
                    xmin = 0, xmax = 10, xnbin = 10,
                    xtitle = 'n Razzled Photons'
                    )
plt.show()
#----------------------------------------------
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_pfp_razzled_photon_score', 
                    scaleHNLPlot,
                    xmin = 0, xmax = 1, xnbin = 40,
                    xtitle = 'PFP Razzled Photon Score'
                    )
plt.show()
# Out:
# nSig = 27596.1, nBkg = 54972.5, nSlc = 82568.6
# purity = 33.4
# eff = 33.3
# select eff = 35
# nSig = 27596.1, nBkg = 54972.5, nSlc = 82568.6
# purity = 33.4
# eff = 33.3
# select eff = 35

# %%
df_hnl = cutPhoton(df_hnl, nPhoton = 2, ifScore = False)
df_nu = cutPhoton(df_nu, nPhoton = 2, ifScore = False)
df_cos = cutPhoton(df_cos, nPhoton = 2, ifScore = False)

# %%
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_n_razzled_photons', 
                    scaleHNLPlot,
                    xmin = 0, xmax = 10, xnbin = 10,
                    xtitle = 'n Razzled Photons'
                    )
plt.show()
#----------------------------------------------
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_pfp_razzled_photon_score', 
                    scaleHNLPlot,
                    xmin = 0, xmax = 1, xnbin = 40,
                    xtitle = 'PFP Razzled Photon Score'
                    )
plt.show()
# Out:
# nSig = 27164, nBkg = 52616.4, nSlc = 79780.4
# purity = 34
# eff = 32.8
# select eff = 34.4
# nSig = 27164, nBkg = 52616.4, nSlc = 79780.4
# purity = 34
# eff = 32.8
# select eff = 34.4

# %% [markdown]
# <h1>Shower Topology</h1>

# %%
#Look at only primary shower
def cutHighestShowerE(df):
    df = df[df['slc_pfp_shower_energy'] == df.groupby(['run','subrun','event','slc_idx'])["slc_pfp_shower_energy"].transform(max)]
    return df

df_hnl = cutHighestShowerE(df_hnl) 
df_nu = cutHighestShowerE(df_nu) 
df_cos = cutHighestShowerE(df_cos)

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(12, 4), sharey= True, sharex = True)

xmin, xmax = -180, 180
xnbin = 90

ymin, ymax = 0, 180
ynbin = 90

xlimmin, xlimmax = xmin, xmax
ylimmin, ylimmax = ymin, ymax
#----------------------------------------------
plot_2dhist( df_nu['slc_pfp_shower_phi'], df_nu['slc_pfp_shower_theta'], 
            ax1, fig, 
            xmin, xmax, ymin, ymax, xnbin, ynbin,
            xlimmin, xlimmax, ylimmin, ylimmax,
            weights = df_nu['scale_pot'],
            title = 'Neutrino', xtitle = 'Phi', ytitle= 'Theta'
                )
#----------------------------------------------
plot_2dhist( df_hnl['slc_pfp_shower_phi'], df_hnl['slc_pfp_shower_theta'], 
            ax2, fig, 
            xmin, xmax, ymin, ymax, xnbin, ynbin,
            xlimmin, xlimmax, ylimmin, ylimmax,
            weights = df_hnl['scale_pot'],
            title = 'HNL', xtitle = 'Phi', ytitle= 'Theta'
                )
#----------------------------------------------
plot_2dhist( df_cos['slc_pfp_shower_phi'], df_cos['slc_pfp_shower_theta'], 
            ax3, fig, 
            xmin, xmax, ymin, ymax, xnbin, ynbin,
            xlimmin, xlimmax, ylimmin, ylimmax,
            weights = df_cos['scale_pot'],
            title = 'Cosmics', xtitle = 'Phi', ytitle= 'Theta'
                )
#----------------------------------------------
plt.ylim(0,40)
plt.show()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(12, 4), sharey= True, sharex = True)

xmin, xmax = -180, 180
xnbin = 90

ymin, ymax = 0, 180
ynbin = 90

xlimmin, xlimmax = xmin, xmax
ylimmin, ylimmax = ymin, ymax
#----------------------------------------------
plot_2dhist( df_nu['slc_pfp_track_phi'], df_nu['slc_pfp_track_theta'], 
            ax1, fig, 
            xmin, xmax, ymin, ymax, xnbin, ynbin,
            xlimmin, xlimmax, ylimmin, ylimmax,
            weights = df_nu['scale_pot'],
            title = 'Neutrino', xtitle = 'Phi', ytitle= 'Theta'
                )
#----------------------------------------------
plot_2dhist( df_hnl['slc_pfp_track_phi'], df_hnl['slc_pfp_track_theta'], 
            ax2, fig, 
            xmin, xmax, ymin, ymax, xnbin, ynbin,
            xlimmin, xlimmax, ylimmin, ylimmax,
            weights = df_hnl['scale_pot'],
            title = 'HNL', xtitle = 'Phi', ytitle= 'Theta'
                )
#----------------------------------------------
plot_2dhist( df_cos['slc_pfp_track_phi'], df_cos['slc_pfp_track_theta'], 
            ax3, fig, 
            xmin, xmax, ymin, ymax, xnbin, ynbin,
            xlimmin, xlimmax, ylimmin, ylimmax,
            weights = df_cos['scale_pot'],
            title = 'Cosmics', xtitle = 'Phi', ytitle= 'Theta'
                )
#----------------------------------------------
plt.show()

# %%
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_pfp_shower_theta', 
                    scaleHNLPlot,
                    xmin = 0, xmax = 180, xnbin = 20,
                    xtitle = 'Shower Theta'
                    )
plt.show()
#----------------------------------------------
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_pfp_shower_phi', 
                    scaleHNLPlot,
                    xmin = -180, xmax = 180, xnbin = 90,
                    xtitle = 'Shower Phi'
                    )
plt.show()
# Out:
# nSig = 27164, nBkg = 52616.4, nSlc = 79780.4
# purity = 34
# eff = 32.8
# select eff = 34.4
# nSig = 27164, nBkg = 52616.4, nSlc = 79780.4
# purity = 34
# eff = 32.8
# select eff = 34.4

# %%
df_hnl = cutThetaAngle(df_hnl, thetaAngle = 10) 
df_nu = cutThetaAngle(df_nu, thetaAngle = 10) 
df_cos = cutThetaAngle(df_cos, thetaAngle = 10)

# %%
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_pfp_shower_theta', 
                    scaleHNLPlot,
                    xmin = 0, xmax = 180, xnbin = 20,
                    xtitle = 'Shower Theta'
                    )
plt.show()
#----------------------------------------------
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_pfp_shower_phi', 
                    scaleHNLPlot,
                    xmin = -180, xmax = 180, xnbin = 90,
                    xtitle = 'Shower Phi'
                    )
plt.show()
# Out:
# nSig = 16899.8, nBkg = 2776.41, nSlc = 19676.2
# purity = 85.9
# eff = 20.4
# select eff = 21.4
# nSig = 16899.8, nBkg = 2776.41, nSlc = 19676.2
# purity = 85.9
# eff = 20.4
# select eff = 21.4

# %% [markdown]
# <h1>Track Score</h1>

# %%
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'slc_pfp_track_score', 
                    scaleHNLPlot,
                    xmin = 0, xmax = 1, xnbin = 50,
                    xtitle = 'PFP Track Score'
                    )

plt.xlim(0.4,0.6)
plt.show()
# Out:
# nSig = 16899.8, nBkg = 2776.41, nSlc = 19676.2
# purity = 85.9
# eff = 20.4
# select eff = 21.4

# %%
df_hnl = cutTrackScore(df_hnl, TrackScore = 0.45) 
df_nu = cutTrackScore(df_nu, TrackScore = 0.45) 
df_cos = cutTrackScore(df_cos, TrackScore = 0.45)

# %% [markdown]
# <h1> Make Beam Bucket </h1>

# %%
print(df_hnl['slc_true_event_type'].unique())
print(df_nu['slc_true_event_type'].unique())
print(df_cos['slc_true_event_type'].unique())

# %%
df_hnl['signal']= df_hnl['slc_true_event_type']==0
df_nu['signal']= df_nu['slc_true_event_type']==0
df_cos['signal']= df_cos['slc_true_event_type']==0

# %%
plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'signal', 
                    scaleHNLPlot,
                    xmin = 0, xmax = 2, xnbin = 2,
                    xtitle = 'Signal vs Bkg'
                    )

#plt.ylim(0,10000)
plt.show()

# %%
width = 19.05

df_hnl['mod_t'] = df_hnl['slc_opt0_time_corrected_Z_pandora']%width
df_nu['mod_t'] = df_nu['slc_opt0_time_corrected_Z_pandora']%width
df_cos['mod_t'] = df_cos['slc_opt0_time_corrected_Z_pandora']%width
#----------------------------------------------
hist, bins = plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'mod_t', 
                    scaleHNLPlot,
                    xmin = 0, xmax = 19, xnbin = 19,
                    xtitle = 'Opt0 Time Corrected Z % ' + str(width)
                    )
plt.show()

# %%
print(hist.shape)

# %% [markdown]
# <h1>Make 1D Histogram</h1>

# %%
combinedf = pd.concat([df_hnl, df_nu, df_cos])

# %%
#dataframe are at pfp level --> need to count slice
#combinedf = combinedf.drop_duplicates(subset=["run","subrun","event", "slc_idx"])
    
#keep only relevant columns
combinedf = combinedf[['run', 'subrun', 'event', 'slc_idx', 'mod_t', 'signal','scale_pot','slc_true_event_type']]

# %%
fig, ax = plt.subplots(1, 1, figsize = (6, 4))

xmin = 0
xmax = 20
xnbin = 20

xlimmin = xmin
xlimmax = xmax

#----------------------------------------------
pltdf = dfbkg['mod_t']

nBkg, binBkg, _ = plot_1dhist(
                    pltdf, 
                    ax,
                    xmin, xmax, xnbin,
                    xlimmin, xlimmax,
                    weights = dfbkg['scale_pot'],
                    histtype = 'step',
                    linecolor = col_dict['Teal'],
                    linewidth = 3,
                    label = 'Background',
                    iflabelbox = True
                    )
plt.ylim(0,3000)
plt.show()

#----------------------------------------------
pltdf = dfsig['mod_t']

nSig, binSig, _ = plot_1dhist(
                    pltdf, 
                    ax,
                    xmin, xmax, xnbin,
                    xlimmin, xlimmax,
                    weights = dfsig['scale_pot'],
                    histtype = 'step',
                    linecolor = col_dict['Coral'],
                    linewidth = 3,
                    label = 'Signal Umu = 1e-7',
                    iflabelbox = True
                    )

print('nSig = ' + str(np.sum(nSig)))
print('nBkg = ' + str(np.sum(nBkg)))
print('-----------------------------')
#----------------------------------------------
#plt.xlim(10, 20)
#plt.ylim(0, 500)
plt.show()

plot_slc_var(df_hnl, df_nu, df_cos,
                    true_counts, start_counts, 
                    'mod_t', 
                    1,
                    xmin = 0, xmax = 19, xnbin = 19,
                    xtitle = 'Opt0 Time Corrected Z % ' + str(width)
                    )
plt.ylim(0,3000)
plt.show()

# %%
binMid = np.convolve(binSig, [0.5, 0.5], "valid")

#make background 1 i.e. should get better limits
#bkgFit = np.ones(4)

# %%
lb = 15
binMid = binMid[lb:-2]
sigFit = nSig[lb:-2]
bkgFit = nBkg[lb:-2]

# %%
print(sigFit)
print(bkgFit)
print(binMid)

# %%
fig, ax = plt.subplots(1, 1, figsize = (6, 4))

xmin = binMid[0]
xmax = binMid[-1]
xnbin = len(binMid)

xlimmin = xmin
xlimmax = xmax

#----------------------------------------------
plot_step(binMid, sigFit, 
                ax,
                xlimmin, xlimmax, 
                color = col_dict["Coral"], 
                title = "", xtitle = "", ytitle = "", fontsize = 16,
                ifysci = False, ifxsci = False,
                ifylim = False , ylimmin = None, ylimmax = None,
                iflabelbox = True, label = "Signal", loc = 'best'
                )
#----------------------------------------------
plot_step(binMid, bkgFit, 
                ax,
                xlimmin, xlimmax, 
                color = col_dict["Teal"], 
                title = "", xtitle = "", ytitle = "", fontsize = 16,
                ifysci = False, ifxsci = False,
                ifylim = False , ylimmin = None, ylimmax = None,
                iflabelbox = True, label = "Background", loc = 'best'
                )       
plt.show()

# %% [markdown]
# <h1>Scaling to ~10 events for hypothesis testing </h1>

# %%
print("Before Scaling")
print(sigFit)
print(bkgFit)

# %%
scaleFactor = 200
sigFit = sigFit /scaleFactor

print("After Scaling")
print(sigFit)
print(bkgFit)

# %%
bkgStatErr = 1/np.sqrt(bkgFit)
sigStatErr = 1/np.sqrt(sigFit)

print(bkgStatErr)
print(sigStatErr)

# %%
sigFit = sigFit.tolist()
bkgFit = bkgFit.tolist()
bkgStatErr = bkgStatErr.tolist()
sigStatErr = sigStatErr.tolist()

# %%
scaledU = getUfromScaleFactor(simU, scaleFactor)
print("Simulated Umu = " + str(simU))
print("Scaled Umu for fitting = " +str(scaledU))

# %% [markdown]
# <h1> Counting Experiment / Single Point Fitting</h1>

# %%
import pyhf
import numpy as np
import matplotlib.pyplot as plt
from pyhf.contrib.viz import brazil

# %%
sigTot = 45 #np.sum(sigFit)
sigTotErr = np.sqrt(sigTot)

bkgTot = 1 #np.sum(bkgFit)
bkgTotErr = np.sqrt(bkgTot)

print(sigTot)
print(bkgTot)
print(bkgTotErr)

# %%
model_dict = pyhf.Model(
        {
      "channels": [
        {
          "name": "singlechannel",
          "samples": [
            {
              "name": "signal",
              "data": [sigTot],
              "modifiers": [
                {"name": "mu", "type": "normfactor", "data": None}, #This is the scaling which is to be calculated
                #{"name": "uncorr_siguncrt", "type": "shapesys", "data": [sigTotErr]}
              ]
            },
            {
              "name": "background",
              "data": [bkgTot],
              "modifiers": [
                {"name": "uncorr_bkguncrt", "type": "shapesys", "data": [bkgTotErr]}
              ]
            }
          ]
        }
      ]
    }
    )

print(f'Samples:\n {model_dict.config.samples}')
print(f'Modifiers are:\n {model_dict.config.modifiers}')

# %%
# No DATA --> Data == Background

data = [bkgTot]+model_dict.config.auxdata

# %%
poi_values = np.linspace(0.001, 2, 50)
#poi_values = np.linspace(0, 5, 41)

obs_limit_single, exp_limits_single, (scan, results) = pyhf.infer.intervals.upper_limits.upper_limit(data, 
                                                                                        model_dict, 
                                                                                        poi_values, 
                                                                                        level=0.1, 
                                                                                        return_results=True)

print(f"Upper limit (obs): μ = {obs_limit_single:.4f}")
print(f"Upper limit (exp): μ = {exp_limits_single[2]:.4f}" + "\n")

# %%
EXP_LIMIT = np.sqrt(exp_limits_single[2])*scaledU
LIMIT = np.sqrt(obs_limit_single)*scaledU
print(f"Expected limit is " + str(EXP_LIMIT))
print(f"Observed limit is " + str(LIMIT)+ "\n")

# %% [markdown]
# <h1>Simple Model Fit</h1>

# %%
pyhf.set_backend("numpy")

model = pyhf.simplemodels.uncorrelated_background(
    signal=sigFit
    , bkg=bkgFit
    , bkg_uncertainty=bkgStatErr
)

data = bkgFit + model.config.auxdata

poi_vals = np.linspace(0, 1, 41)


results = [
    pyhf.infer.hypotest(
        test_poi, data, model, test_stat="qtilde", return_expected_set=True
    )
    for test_poi in poi_vals
]

fig, ax = plt.subplots()
fig.set_size_inches(7, 5)
brazil.plot_results(poi_vals, results, ax=ax)
plt.ylim(0.0,0.2)
fig.show()

# %% [markdown]
# <h1>More Complicated Model Fit</h1>

# %%
model_dict = pyhf.Model(
        {
      "channels": [
        {
          "name": "singlechannel",
          "samples": [
            {
              "name": "signal",
              "data": sigFit,
              "modifiers": [
                {"name": "mu", "type": "normfactor", "data": None}, #This is the scaling which is to be calculated
                {"name": "uncorr_siguncrt", "type": "shapesys", "data": sigStatErr}
              ]
            },
            {
              "name": "background",
              "data": bkgFit,
              "modifiers": [
                {"name": "uncorr_bkguncrt", "type": "shapesys", "data": bkgStatErr}
              ]
            }
          ]
        }
      ]
    }
    )

print(f'Samples:\n {model_dict.config.samples}')
print(f'Modifiers are:\n {model_dict.config.modifiers}')

# %%
# No DATA --> Data == Background

data = bkgFit+model_dict.config.auxdata

# %%
poi_values = np.linspace(0.001, 2, 50)
#poi_values = np.linspace(0, 5, 41)

obs_limit_single, exp_limits_single, (scan, results) = pyhf.infer.intervals.upper_limits.upper_limit(data, 
                                                                                        model_dict, 
                                                                                        poi_values, 
                                                                                        level=0.1, 
                                                                                        return_results=True)

print(f"Upper limit (obs): μ = {obs_limit_single:.4f}")
print(f"Upper limit (exp): μ = {exp_limits_single[2]:.4f}" + "\n")

# %%
test_mu = obs_limit_single

test_mu = 0.10

CLs_obs, p_values = pyhf.infer.hypotest(
    test_mu
    , data
    , model_dict
    , test_stat="qtilde"
    , return_tail_probs=True
)
print(f"Observed CL_s: {CLs_obs}, CL_sb: {p_values[0]}, CL_b: {p_values[1]}")

# %% [markdown]
# <h1>Derive Limit</h1>

# %%
EXP_LIMIT = np.sqrt(exp_limits_single[2])*scaledU
LIMIT = np.sqrt(obs_limit_single)*scaledU
print(f"Expected limit is " + str(EXP_LIMIT))
print(f"Observed limit is " + str(LIMIT)+ "\n")

# %%
EXP_LIMIT = np.sqrt(exp_limits_single[2])*scaledU
LIMIT = np.sqrt(obs_limit_single)*scaledU
print(f"Expected limit is " + str(EXP_LIMIT))
print(f"Observed limit is " + str(LIMIT)+ "\n")
